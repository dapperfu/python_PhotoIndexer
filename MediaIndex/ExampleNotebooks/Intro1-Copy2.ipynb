# %%
import get_files
from cached_property import cached_property

import MediaIndexer
import MediaIndexer.redis_cache
import MediaIndexer.redis_db

# %%
MediaIndexer.redis_db.databases
# Out:
# {'rq': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=60>>>,
#  'rq_thumb': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=61>>>,
#  'rq_cache': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=62>>>,
#  'xxhash': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=11>>>,
#  'exif': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=12>>>,
#  'thumb': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=13>>>}

# %%
for jpeg in get_files.get_files(
    "/vault/pictures/2006/RoadTrips/Road Trip - May 2006/", extensions=".jpg"
):
    break
jpeg
# Out:
# '/vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg'

# %%
MediaIndexer.redis_cache.get_xxhash(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg
# 'a2a14835dc4d8f3a'

# %%
MediaIndexer.redis_cache.get_xxhash(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg
# 'a2a14835dc4d8f3a'

# %%
MediaIndexer.redis_cache.get_thumbnail(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg
# ...

# %%
tn = MediaIndexer.utils.pil_thumbnail(
    MediaIndexer.redis_cache.get_thumbnail(jpeg)
)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - May 2006/Day 5/060520-163020.jpg

# %%
MediaIndexer.redis_cache.get_exif(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060728-173532.jpg
# [X] EXIF : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060728-173532.jpg
# {'SourceFile': '/vault/pictures/2006/RoadTrips/Road Trip - July 2006/060728-173532.jpg',
#  'ExifTool:ExifToolVersion': 10.8,
#  'File:FileName': '060728-173532.jpg',
#  'File:Directory': '/vault/pictures/2006/RoadTrips/Road Trip - July 2006',
#  'File:FileSize': 446763,
#  'File:FileModifyDate': '2009:05:07 16:01:00-04:00',
#  'File:FileAccessDate': '2018:10:04 21:38:55-04:00',
#  'File:FileInodeChangeDate': '2018:08:26 13:40:28-04:00',
#  'File:FilePermissions': 755,
#  'File:FileType': 'JPEG',
#  'File:FileTypeExtension': 'JPG',
#  'File:MIMEType': 'image/jpeg',
#  'File:ExifByteOrder': 'II',
#  'File:ImageWidth': 2304,
#  'File:ImageHeight': 3072,
#  'File:EncodingProcess': 2,
#  'File:BitsPerSample': 8,
#  'File:ColorComponents': 3,
#  'File:YCbCrSubSampling': '2 2',
#  'JFIF:JFIFVersion': '1 1',
# ...

# %%
MediaIndexer.redis_cache.cache_dir?

# %%
for idx, jpeg in enumerate(
    get_files.get_files("/vault/pictures/2006/RoadTrips/", extensions=".jpg")
):
    objs = MediaIndexer.redis_cache.cache_thumbnail(jpeg)
    print(objs)

    if idx > 100:
        break
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# None
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-210230.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-210230.jpg
# None
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060727-162813.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060727-162813.jpg
# None
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204020.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204020.jpg
# None
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060729-194037.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060729-194037.jpg
# None
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/IMG_6335.jpg
# ...

# %%
for idx, jpeg in enumerate(
    get_files.get_files("/vault/pictures/2006/RoadTrips/", extensions=".jpg")
):
    break
    objs = MediaIndexer.redis_cache.cache_thumbnail(jpeg)
    print(objs)

    if idx > 100:
        break

# %%
tn = MediaIndexer.redis_cache.get_thumbnail(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg

# %%
tn
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00\xbf\x00\xff\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd
# ...

# %%
tn_ = MediaIndexer.utils.pil_thumbnail(tn)
tn_
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x191 at 0x7FC37D1DE208>

# %%
classifier.detect(tn_)
# Out:
# [Classified<truck, (6.75, 82.65947723388672, 253.40234375, 193.8581314086914)>,
#  Classified<car, (21.04540252685547, 93.45844650268555, 256.69507598876953, 198.13502883911133)>]

# %%
class Img(object):
    def __init__(self, path):
        self.path = path

    @cached_property
    def objects(self):
        return classifier.detect(self.path)

# %%
jpeg
# Out:
# '/vault/pictures/2006/RoadTrips/Road Trip - July 2006/060728-172857.jpg'

# %%
for idx, jpeg in enumerate(
    get_files.get_files("/vault/pictures/2006/RoadTrips/", extensions=".jpg")
):
    break

# %%
I = Img(jpeg)

# %%
I.objects
# Out:
# [Classified<truck, (556.06005859375, 1207.9968872070312, 3070.83154296875, 2317.9889526367188)>,
#  Classified<car, (45.1851806640625, 1163.88525390625, 3092.8592529296875, 2370.466796875)>]

# %%
i = I.objects[0]

# %%
MediaIndexer.redis_cache.get_xxhash(jpeg)
# Out:
# [ ] hash: /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# 'f782a37e80f92be8'

# %%
MediaIndexer.redis_cache.get_xxhash(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# 'f782a37e80f92be8'

# %%
MediaIndexer.redis_cache.get_exif(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# [ ] EXIF: /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# {'SourceFile': '/vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg',
#  'ExifTool:ExifToolVersion': 10.8,
#  'File:FileName': '060723-204029.jpg',
#  'File:Directory': '/vault/pictures/2006/RoadTrips/Road Trip - July 2006',
#  'File:FileSize': 1863550,
#  'File:FileModifyDate': '2009:05:07 16:00:38-04:00',
#  'File:FileAccessDate': '2018:10:04 20:52:09-04:00',
#  'File:FileInodeChangeDate': '2018:08:26 13:40:28-04:00',
#  'File:FilePermissions': 755,
#  'File:FileType': 'JPEG',
#  'File:FileTypeExtension': 'JPG',
#  'File:MIMEType': 'image/jpeg',
#  'File:ExifByteOrder': 'II',
#  'File:ImageWidth': 3072,
#  'File:ImageHeight': 2304,
#  'File:EncodingProcess': 0,
#  'File:BitsPerSample': 8,
#  'File:ColorComponents': 3,
#  'File:YCbCrSubSampling': '2 1',
#  'EXIF:Make': 'Canon',
# ...

# %%
MediaIndexer.redis_cache.get_thumbnail(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# [ ] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# ...

# %%
MediaIndexer.redis_cache.get_thumbnail(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# ...

# %%
tn = MediaIndexer.utils.get_thumbnail(jpeg, pil_image=True)

# %%
tn
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x191 at 0x7FAE1F478208>

# %%
tn_b = MediaIndexer.redis_cache.get_thumbnail(jpeg)
# Out:
# [X] hash : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg
# [X] thumb : /vault/pictures/2006/RoadTrips/Road Trip - July 2006/060723-204029.jpg

# %%
MediaIndexer.utils.pil_thumbnail(tn_b)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x191 at 0x7FAE1F46AD68>

# %%
del classifier
