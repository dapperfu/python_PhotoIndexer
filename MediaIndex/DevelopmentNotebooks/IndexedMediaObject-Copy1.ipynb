# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport MediaIndexer
import os

# %%
config_file = os.path.abspath("../config_m6700.ini")
assert os.path.exists(config_file)

# %%
indexer = MediaIndexer.MediaIndexer(config_file=config_file)

# %%
indexer
# Out:
# MediaIndexer<config_m6700.ini>

# %%
indexer.databases
# Out:
# {'rq': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=60>>>,
#  'rq_thumb': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=61>>>,
#  'rq_cache': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=62>>>,
#  'xxhash': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=11>>>,
#  'exif': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=12>>>,
#  'thumb': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=13>>>}

# %%
test_image = "/tmp/darknet/data/dog.jpg"

# %%
indexer.get_xxhash(test_image)
# Out:
# [X] hash : /tmp/darknet/data/dog.jpg
# '7a4ee943299372fb'

# %%
indexer.get_xxhash(test_image)
# Out:
# [X] hash : /tmp/darknet/data/dog.jpg
# '7a4ee943299372fb'

# %%
indexer.get_thumbnail(test_image)
# Out:
# [X] hash : /tmp/darknet/data/dog.jpg
# [X] thumb : /tmp/darknet/data/dog.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x191 at 0x7EFD58074E10>

# %%
media = MediaIndexer.IndexedMedia(indexer=indexer, file_path=test_image)
media
# Out:
# [X] hash : /tmp/darknet/data/dog.jpg
# IndexedMedia<7a4ee943299372fb>

# %%
media.thumbnail
# Out:
# [X] hash : /tmp/darknet/data/dog.jpg
# [X] thumb : /tmp/darknet/data/dog.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x191 at 0x7EFD58E5FDD8>

# %%
media.exif
# Out:
# [X] hash : /tmp/darknet/data/dog.jpg
# [ ] EXIF: /tmp/darknet/data/dog.jpg
# {'SourceFile': '/tmp/darknet/data/dog.jpg',
#  'ExifTool:ExifToolVersion': 10.8,
#  'File:FileName': 'dog.jpg',
#  'File:Directory': '/tmp/darknet/data',
#  'File:FileSize': 163759,
#  'File:FileModifyDate': '2018:10:10 00:48:54-04:00',
#  'File:FileAccessDate': '2018:10:10 06:57:02-04:00',
#  'File:FileInodeChangeDate': '2018:10:10 00:48:54-04:00',
#  'File:FilePermissions': 664,
#  'File:FileType': 'JPEG',
#  'File:FileTypeExtension': 'JPG',
#  'File:MIMEType': 'image/jpeg',
#  'File:ExifByteOrder': 'MM',
#  'File:CurrentIPTCDigest': 'ea77cae62a2f464e96d52a5ed9b14692',
#  'File:ImageWidth': 768,
#  'File:ImageHeight': 576,
#  'File:EncodingProcess': 0,
#  'File:BitsPerSample': 8,
#  'File:ColorComponents': 3,
#  'File:YCbCrSubSampling': '1 2',
#  'EXIF:ImageDescription': '                               ',
#  'EXIF:Make': 'Canon',
#  'EXIF:Model': 'Canon PowerShot S95',
#  'EXIF:Orientation': 1,
# ...

# %%
media.exif
# Out:
# {'SourceFile': '/tmp/darknet/data/dog.jpg',
#  'ExifTool:ExifToolVersion': 10.8,
#  'File:FileName': 'dog.jpg',
#  'File:Directory': '/tmp/darknet/data',
#  'File:FileSize': 163759,
#  'File:FileModifyDate': '2018:10:10 00:48:54-04:00',
#  'File:FileAccessDate': '2018:10:10 06:57:02-04:00',
#  'File:FileInodeChangeDate': '2018:10:10 00:48:54-04:00',
#  'File:FilePermissions': 664,
#  'File:FileType': 'JPEG',
#  'File:FileTypeExtension': 'JPG',
#  'File:MIMEType': 'image/jpeg',
#  'File:ExifByteOrder': 'MM',
#  'File:CurrentIPTCDigest': 'ea77cae62a2f464e96d52a5ed9b14692',
#  'File:ImageWidth': 768,
#  'File:ImageHeight': 576,
#  'File:EncodingProcess': 0,
#  'File:BitsPerSample': 8,
#  'File:ColorComponents': 3,
#  'File:YCbCrSubSampling': '1 2',
#  'EXIF:ImageDescription': '                               ',
#  'EXIF:Make': 'Canon',
#  'EXIF:Model': 'Canon PowerShot S95',
#  'EXIF:Orientation': 1,
#  'EXIF:XResolution': 72,
#  'EXIF:YResolution': 72,
#  'EXIF:ResolutionUnit': 2,
# ...

# %%
media.objects
# Out:
# Loading darknet classifier, one minute.
# Loading network......Done
# Loading metadata......Done
# [Classified<dog, (134.83998107910156, 214.18678283691406, 313.66184997558594, 542.5165863037109)>,
#  Classified<truck, (476.8968048095703, 81.5092544555664, 684.7720184326172, 168.59276580810547)>,
#  Classified<bicycle, (99.2535400390625, 124.20358276367188, 589.5813598632812, 447.6205139160156)>]

# %%
media.objects
# Out:
# [Classified<dog, (134.83998107910156, 214.18678283691406, 313.66184997558594, 542.5165863037109)>,
#  Classified<truck, (476.8968048095703, 81.5092544555664, 684.7720184326172, 168.59276580810547)>,
#  Classified<bicycle, (99.2535400390625, 124.20358276367188, 589.5813598632812, 447.6205139160156)>]

# %%
for obj in media.objects:
    break

# %%
obj
# Out:
# Classified<dog, (134.83998107910156, 214.18678283691406, 313.66184997558594, 542.5165863037109)>

# %%
obj.image
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7EFD58E54F28>

# %%
obj.classification
# Out:
# 'dog'

# %%
obj.crop
# Out:
# <PIL.Image.Image image mode=RGB size=179x329 at 0x7EFD58E83160>

# %%
obj.crop_box
# Out:
# (134.83998107910156, 214.18678283691406, 313.66184997558594, 542.5165863037109)

# %%
import IPython.display

# %%
for obj in media.objects:
    print(obj.classification)
        print(obj.)
    IPython.display.display(obj.crop)
# Out:
# dog
# <PIL.Image.Image image mode=RGB size=179x329 at 0x7EFD58E83160>
# truck
# <PIL.Image.Image image mode=RGB size=208x87 at 0x7EFD58E83C18>
# bicycle
# <PIL.Image.Image image mode=RGB size=491x324 at 0x7EFD58E83E10>

# %%
import glob

# %%
imgs = glob.glob("/tmp/darknet/data/*.jpg")
imgs
# Out:
# ['/tmp/darknet/data/giraffe.jpg',
#  '/tmp/darknet/data/person.jpg',
#  '/tmp/darknet/data/eagle.jpg',
#  '/tmp/darknet/data/scream.jpg',
#  '/tmp/darknet/data/kite.jpg',
#  '/tmp/darknet/data/dog.jpg',
#  '/tmp/darknet/data/horses.jpg']

# %%
medias=list()
for img in imgs:
    media = MediaIndexer.IndexedMedia(indexer=indexer, file_path=img)
    medias.append(media)

# %%
medias
# Out:
# [X] hash : /tmp/darknet/data/giraffe.jpg
# [ ] hash: /tmp/darknet/data/person.jpg
# [ ] hash: /tmp/darknet/data/eagle.jpg
# [ ] hash: /tmp/darknet/data/scream.jpg
# [ ] hash: /tmp/darknet/data/kite.jpg
# [X] hash : /tmp/darknet/data/dog.jpg
# [ ] hash: /tmp/darknet/data/horses.jpg
# [IndexedMedia<4901661b1a9c69e0>,
#  IndexedMedia<5e3736c667aa5c4d>,
#  IndexedMedia<ce53dac1870a9aa3>,
#  IndexedMedia<e52c4e53be563af0>,
#  IndexedMedia<a818cb79311e1a7f>,
#  IndexedMedia<7a4ee943299372fb>,
#  IndexedMedia<7b05a249329cf220>]

# %%
for media in medias:
    IPython.display.display(media.thumbnail)
# Out:
# [X] hash : /tmp/darknet/data/giraffe.jpg
# [X] thumb : /tmp/darknet/data/giraffe.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x255 at 0x7EFD58E43BA8>
# [X] hash : /tmp/darknet/data/person.jpg
# [ ] thumb : /tmp/darknet/data/person.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x168 at 0x7EFD58E43A20>
# [X] hash : /tmp/darknet/data/eagle.jpg
# [ ] thumb : /tmp/darknet/data/eagle.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x168 at 0x7EFD58E43B70>
# [X] hash : /tmp/darknet/data/scream.jpg
# [ ] thumb : /tmp/darknet/data/scream.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x255 at 0x7EFD58E432E8>
# [X] hash : /tmp/darknet/data/kite.jpg
# [ ] thumb : /tmp/darknet/data/kite.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x169 at 0x7EFD5801BB38>
# [X] hash : /tmp/darknet/data/dog.jpg
# [X] thumb : /tmp/darknet/data/dog.jpg
# ...

# %%
for media in medias:
    IPython.display.display(media.thumbnail)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x255 at 0x7EFD58E43BA8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x168 at 0x7EFD58E43A20>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x168 at 0x7EFD58E43B70>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x255 at 0x7EFD58E432E8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x169 at 0x7EFD5801BB38>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x191 at 0x7EFD5801B828>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x168 at 0x7EFD58E43400>

# %%
for media in medias:
    print(media.objs)
