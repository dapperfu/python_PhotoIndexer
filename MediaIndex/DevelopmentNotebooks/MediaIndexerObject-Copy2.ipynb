# %%
# %load_ext autoreload
# %autoreload 1
# %aimport MediaIndexer

# %%
import os

# %%
cfg = "../config_m6700.ini"
assert os.path.exists(cfg)

# %%
m = MediaIndexer.MediaIndexer(config=cfg)

# %%
m.databases
# Out:
# {'rq': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=60>>>,
#  'rq_thumb': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=61>>>,
#  'rq_cache': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=62>>>,
#  'xxhash': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=11>>>,
#  'exif': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=12>>>,
#  'thumb': StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=13>>>}

# %%
m.get_xxhash("/pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg")
# Out:
# [X] hash : /pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg
# '8502b1f12ef853a5'

# %%
m.get_exif("/pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg")
# Out:
# [X] hash : /pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg
# [X] EXIF : /pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg
# {'SourceFile': '/pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg',
#  'ExifTool:ExifToolVersion': 10.8,
#  'File:FileName': '20170916_122222.jpg',
#  'File:Directory': '/pictures/2018-03-02T16_00_01-05_00/DCIM/Camera',
#  'File:FileSize': 4803204,
#  'File:FileModifyDate': '2017:09:16 13:22:22-04:00',
#  'File:FileAccessDate': '2018:10:10 01:48:58-04:00',
#  'File:FileInodeChangeDate': '2018:08:16 12:25:10-04:00',
#  'File:FilePermissions': 777,
#  'File:FileType': 'JPEG',
#  'File:FileTypeExtension': 'JPG',
#  'File:MIMEType': 'image/jpeg',
#  'File:ExifByteOrder': 'II',
#  'File:ImageWidth': 5312,
#  'File:ImageHeight': 2988,
#  'File:EncodingProcess': 0,
#  'File:BitsPerSample': 8,
#  'File:ColorComponents': 3,
#  'File:YCbCrSubSampling': '2 2',
#  'EXIF:ImageWidth': 5312,
#  'EXIF:ImageHeight': 2988,
#  'EXIF:Make': 'samsung',
#  'EXIF:Model': 'SM-N910T',
#  'EXIF:Orientation': 1,
#  'EXIF:XResolution': 72,
#  'EXIF:YResolution': 72,
#  'EXIF:ResolutionUnit': 2,
#  'EXIF:Software': 'N910TUVS2EQG1',
#  'EXIF:ModifyDate': '2017:09:16 12:22:22',
#  'EXIF:YCbCrPositioning': 1,
#  'EXIF:ExposureTime': 0.04166666667,
#  'EXIF:FNumber': 2.2,
#  'EXIF:ExposureProgram': 2,
#  'EXIF:ISO': 125,
#  'EXIF:ExifVersion': '0220',
#  'EXIF:DateTimeOriginal': '2017:09:16 12:22:22',
#  'EXIF:CreateDate': '2017:09:16 12:22:22',
#  'EXIF:ComponentsConfiguration': '1 2 3 0',
#  'EXIF:ShutterSpeedValue': 0.041810236087066,
#  'EXIF:ApertureValue': 2.1961856275741,
#  'EXIF:BrightnessValue': 1.38,
#  'EXIF:ExposureCompensation': 0,
#  'EXIF:MaxApertureValue': 2.20381023175322,
#  'EXIF:MeteringMode': 2,
#  'EXIF:LightSource': 0,
#  'EXIF:Flash': 0,
#  'EXIF:FocalLength': 4.8,
#  'EXIF:UserComment': '\n',
#  'EXIF:FlashpixVersion': '0100',
#  'EXIF:ColorSpace': 1,
#  'EXIF:ExifImageWidth': 5312,
#  'EXIF:ExifImageHeight': 2988,
#  'EXIF:InteropIndex': 'R98',
#  'EXIF:InteropVersion': '0100',
#  'EXIF:SensingMethod': 2,
#  'EXIF:SceneType': 1,
#  'EXIF:ExposureMode': 0,
#  'EXIF:WhiteBalance': 0,
#  'EXIF:FocalLengthIn35mmFormat': 31,
#  'EXIF:SceneCaptureType': 0,
#  'EXIF:ImageUniqueID': 'H16USHH04SA',
#  'EXIF:GPSVersionID': '2 2 0 0',
#  'EXIF:Compression': 6,
#  'EXIF:ThumbnailOffset': 3316,
#  'EXIF:ThumbnailLength': 10057,
#  'EXIF:ThumbnailImage': '(Binary data 10057 bytes, use -b option to extract)',
#  'Composite:Aperture': 2.2,
#  'Composite:ImageSize': '5312x2988',
#  'Composite:Megapixels': 15.872256,
#  'Composite:ScaleFactor35efl': 6.45833333333333,
#  'Composite:ShutterSpeed': 0.04166666667,
#  'Composite:CircleOfConfusion': '0.00465232422640515',
#  'Composite:FOV': 60.2828220228721,
#  'Composite:FocalLength35efl': 31,
#  'Composite:HyperfocalDistance': 2.25107425086311,
#  'Composite:LightValue': 6.53804145321825}

# %%
tn_ = m.get_thumbnail("/pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg")
# Out:
# [X] hash : /pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg
# [X] thumb : /pictures/2018-03-02T16_00_01-05_00/DCIM/Camera/20170916_122222.jpg

# %%
MediaIndexer.utils.pil_thumbnail(tn_)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=255x143 at 0x7F4C9628DD68>

# %%
m.connection
# Out:
# StrictRedis<ConnectionPool<Connection<host=127.0.0.1,port=6379,db=60>>>

# %%
m.queue
# Out:
# Queue('default')

# %%
m.queue.enqueue()
